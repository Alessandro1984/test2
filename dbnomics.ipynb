# %%
from dbnomics import fetch_series, fetch_series_by_api_link
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from dbnomics import fetch_series, fetch_series_by_api_link
#       2 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'dbnomics'

# %%
df1 = fetch_series('AMECO/ZUTN/ESP.1.0.0.0.ZUTN')

# %%
df2 = df1[["original_period", "value"]].dropna()

# %%
df2.isnull().sum()
# Out:
# original_period    0
# value              0
# dtype: int64

# %%
ax = plt.gca()
df2.plot(x = "original_period", y = "value", ax = ax)
# Out:
# <Axes: xlabel='original_period'>
